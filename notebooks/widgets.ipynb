# %%
from py_pilecore.widgets import (
    pile_widget,
    ProjectInformationWidget,
    calculation_params_widget,
    get_calculation_parameters_kwargs,
    get_multi_cpt_result_kwargs
)

import ipywidgets as widgets

# %%
ProjectInformationWidget();

# %%
calculation_params_widget

# %%
calculation_params_widget.children
# Out:
# (HBox(children=(Dropdown(index=1, layout=Layout(width='80px'), options=('Try to', 'Never'), value='Never'), Label(value='use the groundwater level from the CPT source,'))),
# ...

# %%
pile_widget

# %%
pile_widget.children
# Out:
# (VBox(children=(Dropdown(description='Pile specification', layout=Layout(width='60%'), options=('Prefabricated concrete', 'Bored pile (drilling mud, uncased borehole)', 'Screw pile, cast in place, with grout', 'Driven cast-in-place, tube back by driving', 'Driven cast-in-place, tube back by vibration', 'Continuous flight auger pile', 'Custom'), style=DescriptionStyle(description_width='110px'), tooltip='Select a pile specification', value='Prefabricated concrete'), Dropdown(description='Pile shape', index=1, layout=Layout(width='60%'), options=('Round', 'Rectangluar', 'Round with cone tip'), style=DescriptionStyle(description_width='110px'), value='Rectangluar'), Dropdown(description='Settlement curve', layout=Layout(width='60%'), options=('1', '2', '3'), style=DescriptionStyle(description_width='110px'), value='1'), HBox(children=(Checkbox(value=False, description='Smoothness treatment', indent=False, layout=Layout(width='160px')), Stack(children=(HBox(children=(BoundedFloatText(val
# ...
